# %%
from Cells_C import *
import matplotlib.pyplot as plt
import numpy as np

x = LR1CellIto()
x.setito(1)
apds, ts, vs, cais, nais, kis = pacecell(x,pcl=1000,beats=5,beatsave=5,dt=0.05)
plt.plot(ts,vs)
# Out:
# 1 -3.616578841958429e-10
# 2 999.9999999992767
# 3 1999.9999999983672
# 4 3000.0000000017867
# 5 4000.0000000054247
# 6 5000.000000009062
