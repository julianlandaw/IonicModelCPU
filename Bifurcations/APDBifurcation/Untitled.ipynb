% %%
apd = dlmread('LR2bifs_varyisk_iks.txt');
iks = 1.5;
plot(apd(apd(:,3)==iks,1),apd(apd(:,3)==iks,4:end),'.b');
hold on;
iks = 1;
plot(apd(apd(:,3)==iks,1),apd(apd(:,3)==iks,4:end),'.k');
iks = 0.4;
plot(apd(apd(:,3)==iks,1),apd(apd(:,3)==iks,4:end),'.r');

% %%
unique(apd(:,3))
% Out:
% ans =
%
%     0.1000
%     0.2000
%     0.3000
%     0.4000
%     0.5000
%     0.6000
%     0.7000
%     0.8000
%     0.9000
%     1.0000
%     1.1000
%     1.2000
%     1.3000
%     1.4000
%     1.5000

% %%
A = dlmread('TTbifs_varyisk_skh.txt');
%B = dlmread('OHarabifsSK_varyisk_skh.txt');

isk = 10;
pcl = 500;
%hold on;
%plot(B(B(:,1) == pcl & B(:,2)==isk,3),B(B(:,1) == pcl & B(:,2)==isk,4:end),'.b');
%isk = 20;
isk = 1;
%plot(A(A(:,1)==pcl & A(:,2)==isk,3),A(A(:,1) == pcl & A(:,2)==isk,4:end),'.k'); hold on;
isk = 10;
%plot(A(A(:,1)==pcl & A(:,2)==isk,3),A(A(:,1) == pcl & A(:,2)==isk,4:end),'.r');
isk = 50;
plot(A(A(:,1)==pcl & A(:,2)==isk,3),A(A(:,1) == pcl & A(:,2)==isk,4:end),'.b');
axis([1e-3 3e-3 50 400]);
%isk = 100;
%plot(A(A(:,1)==pcl & A(:,2)==isk,3),A(A(:,1) == pcl & A(:,2)==isk,4:end),'.g');
%isk = 200;
%plot(A(A(:,1)==pcl & A(:,2)==isk,3),A(A(:,1) == pcl & A(:,2)==isk,4:end),'.y');

% %%
max(max(B(:,3:end)))
% Out:
% ans =
%
%   246.7500
