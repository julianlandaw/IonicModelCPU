% %%
apds = [];
cais = [];
nais = [];
kis = [];
for ito = 1:0.01:3.5
    A = dlmread(['LR2bifsPCL_1000_ITO_',num2str(ito),'.txt']);
    B = dlmread(['LR2caiPCL_1000_ITO_',num2str(ito),'.txt']);
    C = dlmread(['LR2kiPCL_1000_ITO_',num2str(ito),'.txt']);
    D = dlmread(['LR2naiPCL_1000_ITO_',num2str(ito),'.txt']);
    apds = [apds; A];
    cais = [cais; B];
    kis = [kis; C];
    nais = [nais; D];
end
%dlmwrite('LR2bifs_PCL_1000_float.txt',apds,'delimiter','\t');
%dlmwrite('LR2cai_PCL_1000_float.txt',cais,'delimiter','\t');
%dlmwrite('LR2nai_PCL_1000_float.txt',nais,'delimiter','\t');
%dlmwrite('LR2ki_PCL_1000_float.txt',kis,'delimiter','\t');

% %%
%apds = dlmread('LR2SKbifs_PCL_1000_iup_2_ito_1.txt');
%apds = dlmread('LR2bifs_ITO_2.5_norm.txt');
%cais = dlmread('LR2cai_ITO_2.5_norm.txt');
%nais = dlmread('LR2nai_ITO_2.5_norm.txt');
%kis = dlmread('LR2ki_ITO_2.5_norm.txt');

apds2 = dlmread('LR2bifs_PCL_1000_norm_dt0.025.txt');
%cais = dlmread('LR2cai_PCL_1000_norm.txt');
%nais = dlmread('LR2nai_PCL_1000_norm.txt');
%kis = dlmread('LR2ki_PCL_1000_norm.txt');

%apds = dlmread('LR2bifs_PCL_1000_Miyoshi.txt');
%cais = dlmread('LR2cai_PCL_1000_Miyoshi.txt');
%nais = dlmread('LR2nai_PCL_1000_Miyoshi.txt');
%kis = dlmread('LR2ki_PCL_1000_Miyoshi.txt');

% %%
subplot(2,1,1);
plot(apds(:,2),apds(:,3:end),'.b');
subplot(2,1,2);
plot(apds2(:,2),apds2(:,3:end),'.r');
%nai = nais(:,3:2:end);
%nai = nai(:);
%cai = cais(:,3:2:end);
%cai = cai(:);
%apd = apds(:,3:end);
%apd = apd(:);
%plot(cai - 0.00001*nai,apd,'.b')

% %%
cd '~/IonicModelCPU/Bifurcations/APDBifurcation'
apds = [];
cais = [];
nais = [];
kis = [];
ito = 2.5;
for pcl = 300:5:1500
    A = dlmread(['LR2bifsPCL_',num2str(pcl),'_ITO_',num2str(ito),'.txt']);
    B = dlmread(['LR2caiPCL_',num2str(pcl),'_ITO_',num2str(ito),'.txt']);
    C = dlmread(['LR2kiPCL_',num2str(pcl),'_ITO_',num2str(ito),'.txt']);
    D = dlmread(['LR2naiPCL_',num2str(pcl),'_ITO_',num2str(ito),'.txt']);
    apds = [apds; A];
    cais = [cais; B];
    kis = [kis; C];
    nais = [nais; D];
end
%dlmwrite('LR2bifs_PCL_1000_float.txt',apds,'delimiter','\t');
%dlmwrite('LR2cai_PCL_1000_float.txt',cais,'delimiter','\t');
%dlmwrite('LR2nai_PCL_1000_float.txt',nais,'delimiter','\t');
%dlmwrite('LR2ki_PCL_1000_float.txt',kis,'delimiter','\t');

% %%
plot(apds(:,1),apds(:,3:end),'.b')
