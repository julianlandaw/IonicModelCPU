% %%
apds = dlmread('LR2bifsPCL_1000_varyito_control.txt');
plot(apds(:,2),apds(:,4:end),'.b');

% %%
ap1 = dlmread('~/IonicModelCPU/AP/LR1ap_PCL_830_VAR1_4_VAR2_0.txt');
ap2 = dlmread('~/IonicModelCPU/AP/LR1ap_PCL_831_VAR1_4_VAR2_0.txt');
plot(ap2(1:1000,1),ap2(1:1000,2));
